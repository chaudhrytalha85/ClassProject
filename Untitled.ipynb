# %%
import pandas as pd

# %%
bchi = pd.read_csv('~/Desktop/Intro_Data_Sci/project/data/BCHI-dataset_2019-03-04.csv')

# %%
bchi.sample(15)
# Out:
#                       Indicator Category  \
# 7514                     Chronic Disease
# 33811        Social and Economic Factors
# 21212                    Injury/Violence
# 1005   Behavioral Health/Substance Abuse
# 26362          Maternal and Child Health
# 26521          Maternal and Child Health
# 15165                           HIV/AIDS
# 4758                     Chronic Disease
# 5908                     Chronic Disease
# 28596    Sexually Transmitted Infections
# 9363                        Demographics
# 32015        Social and Economic Factors
# 11525                       Demographics
# 256    Behavioral Health/Substance Abuse
# 16594                           HIV/AIDS
#
#                                                Indicator  Year   Sex  \
# 7514               Percent of Adults Who Currently Smoke  2013  Both
# 33811                    Percent of Population Uninsured  2016  Both
# 21212  Firearm-Related Emergency Department Visit Rat...  2011  Both
# ...

# %%
bchi.groupby('Indicator Category').nunique()
# Out:
#                                           Indicator Category  Indicator  Year  \
# Indicator Category
# Behavioral Health/Substance Abuse                          1          3     7
# Cancer                                                     1          3     7
# Chronic Disease                                            1          9     7
# Demographics                                               1          9     5
# Environment                                                1          4     8
# Food Safety                                                1          2     7
# HIV/AIDS                                                   1          4     7
# Infectious Disease                                         1          5     7
# Injury/Violence                                            1          5     7
# Life Expectancy and Death Rate (Overall)                   1          2     7
# Maternal and Child Health                                  1          3     7
# ...

# %%
[x for x in bchi.Indicator.unique() if 'ese' in x]
# Out:
# ['Percent of Adults Who Are Obese',
#  'Percent of High School Students Who Are Obese']

# %%
bchi.Indicator.unique()
# Out:
# array(['Opioid-Related Unintentional Drug Overdose Mortality Rate (Age-Adjusted; Per 100,000 people)',
#        'Percent of Adults Who Binge Drank',
#        'Percent of High School Students Who Binge Drank',
#        'All Types of Cancer Mortality Rate (Age-Adjusted; Per 100,000 people)',
#        'Female Breast Cancer Mortality Rate (Age-Adjusted; Per 100,000 people)',
#        'Lung Cancer Mortality Rate (Age-Adjusted; Per 100,000 people)',
#        'Asthma Emergency Department Visit Rate (Age-Adjusted; Per 10,000)',
#        'Diabetes Mortality Rate (Age-Adjusted; Per 100,000 people)',
#        'Heart Disease Mortality Rate (Age-Adjusted; Per 100,000 people)',
#        'Percent of Adults Who Are Obese',
#        'Percent of Adults Who Currently Smoke',
#        'Percent of Adults Who Meet CDC-Recommended Physical Activity Levels',
#        'Percent of High School Students Who Are Obese',
#        'Percent of High School Students Who Currently Smoke',
# ...
